# %% [markdown]
# # OOPS Practice

# %%
print("hello world")
# Out:
# hello world

# %%
class Student:

    def __init__(self,name:str):
        self.name = name
        print(name)
s1 = Student(name=1)

# %%
s1 = Student(name=1)
# Out:
# 1

# %%
from pydantic import validate_call

class Student:

    @validate_call
    def __init__(self, name:str):
        self.name = name
        print(name)

# %%
s1 = Student(name=1)
# Out:
# 1
